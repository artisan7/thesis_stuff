# %% [markdown]
# # Retrieving the Dataset

# %%
# claiming the dataset
import pandas as pd

cxr_dataset = pd.read_csv("../features.csv")
cxr_dataset.head()
# Out:
#    Unnamed: 0      mean0    variance0  skewness0  uniformity0      snr0  \
# 0           0  70.153934  1897.820090   0.155578          154  1.610366
# 1           1  67.943420  1640.924326   0.179606          158  1.677271
# 2           2  85.324244  1666.530997  -0.291033          153  2.090094
# 3           3  84.536424  1134.304302  -0.575772          129  2.510031
# 4           4  97.321200  1344.070831  -0.521123          164  2.654583
#
#         mean1    variance1  skewness1  uniformity1  ...  variance14  \
# 0   67.820031  1431.488738   0.101886          149  ...         0.0
# 1   62.438356  1516.524282   0.382945          153  ...         0.0
# 2   61.805752  1425.903805   0.326995          145  ...         0.0
# 3   85.243692   957.789884  -0.289562          136  ...         0.0
# 4  102.034224  1417.579232  -0.313052          155  ...         0.0
#
#    skewness14  uniformity14  snr14      mean15  variance15  skewness15  \
# 0         0.0             0    0.0    0.000000    0.000000    0.000000
# 1         0.0             0    0.0  125.818182   59.954257    0.105233
# 2         0.0             0    0.0    0.000000    0.000000    0.000000
# 3         0.0             0    0.0  105.758879  247.749337   -0.316222
# 4         0.0             0    0.0  121.310059  518.784337   -0.373516
#
#    uniformity15      snr15     label
# 0             0   0.000000  COVID-19
# 1            38  16.249253  COVID-19
# 2             0   0.000000  COVID-19
# 3            64   6.719092  COVID-19
# 4            95   5.326027  COVID-19
#
# [5 rows x 82 columns]

# %%
cxr_dataset['label'].replace(['No Finding', 'Pneumonia'], 'No COVID-19', inplace=True)

for i in range(100, 300, 2):
    cxr_dataset.drop(i, inplace=True)

cxr_dataset.shape
# Out:
# (200, 82)

# %% [markdown]
# # Splitting the dataset to train and test

# %%
# Getting the features needed

#get the feature columns
col_features = list(cxr_dataset.columns)
#get the label column
label = list(cxr_dataset.columns).pop()
#deleting label column from col
del col_features[0]
del col_features[len(col_features) - 1]

features = cxr_dataset.loc[:, col_features].values
labels = cxr_dataset.loc[:, label].values

display(pd.DataFrame(features))
# Out:
#             0            1         2      3         4           5   \
# 0    70.153934  1897.820090  0.155578  154.0  1.610366   67.820031
# 1    67.943420  1640.924326  0.179606  158.0  1.677271   62.438356
# 2    85.324244  1666.530997 -0.291033  153.0  2.090094   61.805752
# 3    84.536424  1134.304302 -0.575772  129.0  2.510031   85.243692
# 4    97.321200  1344.070831 -0.521123  164.0  2.654583  102.034224
# ..         ...          ...       ...    ...       ...         ...
# 195  63.307311   837.895647  0.337161  113.0  2.187051   55.658719
# 196  85.093584  1203.716374 -0.203081  149.0  2.452645   52.556969
# 197  67.485362   590.801404  0.125502  101.0  2.776443   58.764064
# 198  52.461857   967.863802  0.288745  120.0  1.686307   58.074462
# 199  54.742072   804.571951  0.265591  110.0  1.929918   46.046397
#
#               6         7      8         9   ...          70          71  \
# 0    1431.488738  0.101886  149.0  1.792520  ...    0.000000    0.000000
# 1    1516.524282  0.382945  153.0  1.603344  ...    0.000000    0.000000
# 2    1425.903805  0.326995  145.0  1.636755  ...    0.000000    0.000000
# 3     957.789884 -0.289562  136.0  2.754401  ...    0.000000    0.000000
# 4    1417.579232 -0.313052  155.0  2.710018  ...    0.000000    0.000000
# ..           ...       ...    ...       ...  ...         ...         ...
# 195  1034.654916  0.195368  139.0  1.730356  ...    0.000000    0.000000
# 196  1129.101584  0.303695  130.0  1.564097  ...    0.000000    0.000000
# 197  1009.093014 -0.076914  125.0  1.849891  ...  108.375000   24.734375
# 198   876.051465  0.146898  131.0  1.962097  ...  113.789474    8.060942
# 199  1082.516952  0.390843  125.0  1.399517  ...   92.851852  101.459534
#
#            72    73         74          75           76        77     78  \
# 0    0.000000   0.0   0.000000    0.000000     0.000000  0.000000    0.0
# 1    0.000000   0.0   0.000000  125.818182    59.954257  0.105233   38.0
# 2    0.000000   0.0   0.000000    0.000000     0.000000  0.000000    0.0
# 3    0.000000   0.0   0.000000  105.758879   247.749337 -0.316222   64.0
# 4    0.000000   0.0   0.000000  121.310059   518.784337 -0.373516   95.0
# ..        ...   ...        ...         ...          ...       ...    ...
# 195  0.000000   0.0   0.000000   42.582278  1152.995491  0.814274  120.0
# 196  0.000000   0.0   0.000000   84.073801  1530.142155 -0.594939  106.0
# 197  0.136133   7.0  21.791074   46.903541  1214.512063  0.503447  120.0
# 198 -0.710812   7.0  40.078291   96.602423   387.369465  0.734007  104.0
# 199  0.206195  17.0   9.218158   49.546763  1256.728389  0.340671  115.0
#
#             79
# 0     0.000000
# 1    16.249253
# 2     0.000000
# 3     6.719092
# 4     5.326027
# ..         ...
# 195   1.254051
# 196   2.149289
# 197   1.345875
# 198   4.908235
# 199   1.397638
#
# [200 rows x 80 columns]

# %%
from sklearn.model_selection import train_test_split

# Separating test and train dataset
train_features, test_features, train_lbl, test_lbl = train_test_split( features, labels, test_size=0.2, random_state=0)

# %%
#Standardizing the Dataset
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Fitting of training dataset only
scaler.fit(train_features)

# Apply transform to both the training set and the test set.
train_features = scaler.transform(train_features)
test_features = scaler.transform(test_features)

# %% [markdown]
# # Applying Principal Component Analysis

# %%
# Feeding it to Principal Component Analysis
from sklearn.decomposition import PCA

# 5 different variance
variances = ["100%", "99%", "95%", "90%", "85%"]
pca = [PCA(), PCA(.99), PCA(.95), PCA(.90), PCA(.85)]
# results of each PCA variance
pca_fit = []

for p in pca:
    pca_content = {"fit": None, "transforms": {"train": None, "test": None}}
    pca_content["fit"] = p.fit(train_features)
    pca_content["transforms"]["train"] = p.transform(train_features)
    pca_content["transforms"]["test"] = p.transform(test_features)
    pca_fit.append(pca_content)

# %%
# checking the number of Principal Component
print("From 14 features")
for i in range(len(variances)):
    print(f"Principal Components with {variances[i]} variance:", pca_fit[i]["fit"].n_components_)
# Out:
# From 14 features
# Principal Components with 100% variance: 80
# Principal Components with 99% variance: 55
# Principal Components with 95% variance: 37
# Principal Components with 90% variance: 27
# Principal Components with 85% variance: 22

# %% [markdown]
# # Applying Linear Discriminant Analysis

# %% [markdown]
# ### Libraries Needed

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score

import numpy as np

lda = LinearDiscriminantAnalysis()

# %% [markdown]
# ### With Principal Component Analysis

# %%
# Evaluating of Model
for i in range(len(pca_fit)):
    # define model evaluation method
    cv = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    # evaluate model
    scores = cross_val_score(lda, pca_fit[i]["transforms"]["train"], np.ravel(train_lbl), scoring='accuracy', cv=cv)
    # summarize result
    print('Variance of %s:\nMean Accuracy: %.4f (%.4f)\n' % (variances[i], np.mean(scores), np.std(scores)))
# Out:
# Variance of 100%:
# Mean Accuracy: 0.6625 (0.0696)
#
# Variance of 99%:
# Mean Accuracy: 0.6500 (0.1287)
#
# Variance of 95%:
# Mean Accuracy: 0.6438 (0.1084)
#
# Variance of 90%:
# Mean Accuracy: 0.6438 (0.1454)
#
# Variance of 85%:
# Mean Accuracy: 0.6687 (0.1010)

# %%
#Train the model
results = [] # where all the results will place

for i in range(len(pca_fit)):
    lda.fit(pca_fit[i]["transforms"]["train"], np.ravel(train_lbl))
    predictions = lda.predict(pca_fit[i]["transforms"]["test"])
    results.append(predictions)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

for i in range(len(pca_fit)):
    print("Variance of", variances[i])
    print("Accuracy Score -", accuracy_score(test_lbl, results[i]))
    
    print("Confusion Matrix")
    print(confusion_matrix(test_lbl, results[i]))
    
    print("Classification Report")
    print(classification_report(test_lbl, results[i]))
    
    print()
# Out:
# Variance of 100%
# Accuracy Score - 0.625
# Confusion Matrix
# [[12  6]
#  [ 9 13]]
# Classification Report
#               precision    recall  f1-score   support
#
#     COVID-19       0.57      0.67      0.62        18
#  No COVID-19       0.68      0.59      0.63        22
#
#     accuracy                           0.62        40
#    macro avg       0.63      0.63      0.62        40
# weighted avg       0.63      0.62      0.63        40
#
#
# Variance of 99%
# Accuracy Score - 0.75
# Confusion Matrix
# [[15  3]
#  [ 7 15]]
# Classification Report
#               precision    recall  f1-score   support
#
#     COVID-19       0.68      0.83      0.75        18
#  No COVID-19       0.83      0.68      0.75        22
#
#     accuracy                           0.75        40
#    macro avg       0.76      0.76      0.75        40
# weighted avg       0.77      0.75      0.75        40
#
#
# Variance of 95%
# Accuracy Score - 0.8
# Confusion Matrix
# [[16  2]
#  [ 6 16]]
# Classification Report
#               precision    recall  f1-score   support
#
#     COVID-19       0.73      0.89      0.80        18
#  No COVID-19       0.89      0.73      0.80        22
#
#     accuracy                           0.80        40
#    macro avg       0.81      0.81      0.80        40
# weighted avg       0.82      0.80      0.80        40
#
#
# Variance of 90%
# Accuracy Score - 0.8
# Confusion Matrix
# [[15  3]
#  [ 5 17]]
# Classification Report
#               precision    recall  f1-score   support
#
#     COVID-19       0.75      0.83      0.79        18
#  No COVID-19       0.85      0.77      0.81        22
#
#     accuracy                           0.80        40
#    macro avg       0.80      0.80      0.80        40
# weighted avg       0.81      0.80      0.80        40
#
#
# Variance of 85%
# Accuracy Score - 0.825
# Confusion Matrix
# [[16  2]
#  [ 5 17]]
# Classification Report
#               precision    recall  f1-score   support
#
#     COVID-19       0.76      0.89      0.82        18
#  No COVID-19       0.89      0.77      0.83        22
#
#     accuracy                           0.82        40
#    macro avg       0.83      0.83      0.82        40
# weighted avg       0.83      0.82      0.83        40

# %% [markdown]
# ### Without Principal Component Analysis

# %%
# Performing towards the untransformed dataset

# define model evaluation method
cv = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)

# evaluate model
scores = cross_val_score(lda, train_features, np.ravel(train_lbl), scoring='accuracy', cv=cv)

# summarize result
print('Linear Discriminant Analysis Cross Validation Score:\nMean Accuracy - %.4f (%.4f)\n' % (np.mean(scores), np.std(scores)))
# Out:
# Linear Discriminant Analysis Cross Validation Score:
# Mean Accuracy - 0.6625 (0.0696)

# %%
lda.fit(train_features, np.ravel(train_lbl))
predictions = lda.predict(test_features)

# %%
print("Linear Disriminant Analysis Performance")
print("Accuracy Score -", accuracy_score(test_lbl, predictions))

print("Confusion Matrix")
print(confusion_matrix(test_lbl, predictions))

print("Classification Report")
print(classification_report(test_lbl, predictions))
# Out:
# Linear Disriminant Analysis Performance
# Accuracy Score - 0.625
# Confusion Matrix
# [[12  6]
#  [ 9 13]]
# Classification Report
#               precision    recall  f1-score   support
#
#     COVID-19       0.57      0.67      0.62        18
#  No COVID-19       0.68      0.59      0.63        22
#
#     accuracy                           0.62        40
#    macro avg       0.63      0.63      0.62        40
# weighted avg       0.63      0.62      0.63        40
